# %% [markdown]
# ## K-Fold Results

# %% [markdown]
# ## Used libraries

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Load the KFold Results

# %%
data = []
for i in range(6): 
    data.append( np.load('./kfolds_reg/{}.npy'.format(i))[0] )

# %%
data = np.array(data)
data
# Out:
# array([[0.50710249, 7.23607254, 0.71381009],
#        [0.65160924, 9.95827961, 0.26670653],
#        [0.54343647, 7.81541777, 0.66577625],
#        [0.62227738, 9.16745472, 0.51654172],
#        [0.61200124, 8.93396664, 0.69982898],
#        [0.42865145, 5.04993248, 0.85434353]])

# %%
data.shape
# Out:
# (6, 3)

# %% [markdown]
# ## Plots

# %%
# Create figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns
x = [x for x in range(1, 7)]

# First plot
ax1.plot(x, data[:, -2], color='blue')
ax1.set_title('Cost Function')
ax1.set_xlabel('K-Fold')
ax1.set_ylabel('MAE')

# Second plot
ax2.plot(x, data[:, -1], color='red')
ax2.set_title('Determination Coefficiente')
ax2.set_xlabel('K-Fold')
ax2.set_ylabel(r'$R^{2}$')

plt.tight_layout()
plt.show()

# %%
print( 'MAE: {:.2f} STD: {:.2f} - HB: {:.2f}'.format(
    np.mean(data[:, -2]), 
    np.std(data[:, -2]), 
    (np.mean(data[:, -2]) + np.std(data[:, -2])) 
     ) )
# Out:
# MAE: 8.03 STD: 1.60 - HB: 9.63

# %%
print( 'R2: {:.2f} STD: {:.2f} - LB: {:.2f}'.format(
    np.mean(data[:, -1]), 
    np.std(data[:, -1]), 
    (np.mean(data[:, -1]) - np.std(data[:, -1])) 
))
# Out:
# R2: 0.62 STD: 0.19 - LB: 0.43

# %% [markdown]
# ## K-Fold Results

# %% [markdown]
# ## Used libraries

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Load the KFold Results

# %%
data = []
for i in range(6): 
    data.append( np.load('./kfolds_reg//{}.npy'.format(i))[0] )

# %%
data = np.array(data)
data
# Out:
# array([[ 1.65665209e+00,  9.63885307e+00,  4.67000127e-01],
#        [ 1.52621377e+00,  9.88880825e+00, -2.73668766e-03],
#        [ 6.62874222e-01,  4.86234713e+00,  8.29620242e-01],
#        [ 1.62550640e+00,  7.98540115e+00,  6.76312566e-01],
#        [ 1.14740860e+00,  8.43065357e+00,  7.27149367e-01],
#        [ 2.80798578e+00,  9.96357059e+00,  2.37224996e-01]])

# %%
data.shape
# Out:
# (6, 3)

# %% [markdown]
# ## Plots

# %%
# Create figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns
x = [x for x in range(1, 7)]

# First plot
ax1.plot(x, data[:, -2], color='blue')
ax1.set_title('Cost Function')
ax1.set_xlabel('K-Fold')
ax1.set_ylabel('MAE')

# Second plot
ax2.plot(x, data[:, -1], color='red')
ax2.set_title('Determination Coefficiente')
ax2.set_xlabel('K-Fold')
ax2.set_ylabel(r'$R^{2}$')

plt.tight_layout()
plt.show()

# %%
print( 'MAE: {:.2f} STD: {:.2f}'.format(np.mean(data[:, -2]), np.std(data[:, -2])) )
# Out:
# MAE: 8.46 STD: 1.77

# %%
print( 'R2: {:.2f} STD: {:.2f}'.format(np.mean(data[:, -1]), np.std(data[:, -1])) )
# Out:
# R2: 0.49 STD: 0.29
